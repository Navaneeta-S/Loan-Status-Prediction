# %% [markdown]
# # Data Understanding

# %%
#importing neccessery libraries
import pandas as pd
import numpy as np

# %%
#reading and displaying the dataset
loan = pd.read_csv('loan.csv')
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0       128.0             360.0
# 1             3000                0.0        66.0             360.0
# 2             2583             2358.0       120.0             360.0
# 3             6000                0.0       141.0             360.0
# 4             2333             1516.0        95.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0         Urban           Y
# ...

# %%
#checking on the type of dataset
type(loan)
# Out:
# pandas.core.frame.DataFrame

# %%
#checking the number of rows and columns
loan.shape
# Out:
# (381, 13)

# %%
#checking the data types
loan.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
#checking if there any missing values presented in the dataset
loan.isna().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#checking for the unique values in each columns
uniqueValues = loan.nunique()
print(uniqueValues)
# Out:
# Loan_ID              381
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      322
# CoapplicantIncome    182
# LoanAmount           101
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
#imputing the missing values using mode
loan['Gender'] = loan['Gender'].fillna(loan['Gender'].mode()[0])

# %%
loan['Dependents'] = loan['Dependents'].replace(['3+'], '3')
loan['Dependents'] = loan['Dependents'].fillna(loan['Dependents'].mode()[0])

# %%
loan['Self_Employed'] = loan['Self_Employed'].fillna(loan['Self_Employed'].mode()[0])

# %%
loan['Loan_Amount_Term'] = loan['Loan_Amount_Term'].fillna(loan['Loan_Amount_Term'].mode()[0])

# %%
loan['Credit_History'] = loan['Credit_History'].fillna(loan['Credit_History'].mode()[0])

# %%
loan.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
Gender = loan['Gender'].value_counts()
Gender.plot(kind = 'bar', color= ['lightblue', 'lightpink'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Gender')
# Out:
# Text(0.5, 1.0, 'Plot of Gender')

# %%
Married = loan['Married'].value_counts()
Married.plot(kind = 'bar', color= ['lightblue', 'lightpink'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Marital Status')
# Out:
# Text(0.5, 1.0, 'Plot of Marital Status')

# %%
Education = loan['Education'].value_counts()
Education.plot(kind = 'bar', color= ['lightblue', 'lightpink'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Education Level')
# Out:
# Text(0.5, 1.0, 'Plot of Education Level')

# %%
Employment = loan['Self_Employed'].value_counts()
Employment.plot(kind = 'bar', color= ['lightblue', 'lightpink'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Self Employed')
# Out:
# Text(0.5, 1.0, 'Plot of Self Employed')

# %%
Loan_Amount_Term = loan['Loan_Amount_Term'].value_counts()
Loan_Amount_Term.plot(kind = 'bar', color= ['lightblue', 'lightpink', 'lightgreen', 'orange'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Loan Amount Term')
# Out:
# Text(0.5, 1.0, 'Plot of Loan Amount Term')

# %%
Credit_History = loan['Credit_History'].value_counts()
Credit_History.plot(kind = 'bar', color= ['lightblue', 'lightpink'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Credit History')
# Out:
# Text(0.5, 1.0, 'Plot of Credit History')

# %%
Property_Area = loan['Property_Area'].value_counts()
Property_Area.plot(kind = 'bar', color= ['lightblue', 'lightpink', 'orange'], edgecolor='black', figsize = (5,5))
plt.title('Plot of Property Area')
# Out:
# Text(0.5, 1.0, 'Plot of Property Area')

# %%
colors = ['#ff9999','#66b3ff']
loan_status = loan['Loan_Status'].value_counts()
loan_status.plot(kind = 'pie', figsize = (5,5), colors=colors, autopct='%1.1f%%')
plt.title('Plot of Loan Status')
# Out:
# Text(0.5, 1.0, 'Plot of Loan Status')

# %%
plt.figure(figsize=(8, 6))  
plt.hist(loan['ApplicantIncome'], color='lightblue', edgecolor='black')
plt.title('Histogram of Applicant Income')  
plt.xlabel('Income')  
plt.ylabel('Frequency')   
plt.show()

# %%
plt.figure(figsize=(8, 6))  
plt.hist(loan['CoapplicantIncome'], color='lightblue', edgecolor='black')
plt.title('Histogram of Coapplicant Income')  
plt.xlabel('Income')  
plt.ylabel('Frequency')   
plt.show()

# %%
plt.figure(figsize=(8, 6))  
plt.hist(loan['LoanAmount'], color='lightblue', edgecolor='black')
plt.title('Histogram of Loan Amount')  
plt.xlabel('Amount')  
plt.ylabel('Frequency')   
plt.show()

# %% [markdown]
# # Data Pre-processing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
columns = ['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
label_encoder = LabelEncoder()
for col in columns:
    loan[col + '_encoded'] = label_encoder.fit_transform(loan[col])
loan = loan.drop(columns=columns)

# %%
loan.head()
# Out:
#     Loan_ID Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  LP001003          1             4583             1508.0       128.0
# 1  LP001005          0             3000                0.0        66.0
# 2  LP001006          0             2583             2358.0       120.0
# 3  LP001008          0             6000                0.0       141.0
# 4  LP001013          0             2333             1516.0        95.0
#
#    Loan_Amount_Term  Credit_History  Gender_encoded  Married_encoded  \
# 0             360.0             1.0               1                1
# 1             360.0             1.0               1                1
# 2             360.0             1.0               1                1
# 3             360.0             1.0               1                0
# 4             360.0             1.0               1                1
#
#    Education_encoded  Self_Employed_encoded  Property_Area_encoded  \
# ...

# %% [markdown]
# # Modelling

# %%
X = loan.drop(['Loan_ID', 'Loan_Status_encoded'], axis=1)
Y = loan['Loan_Status_encoded']

# %%
#To balance the imbalanced class
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=123)
Xtrain_balanced, Ytrain_balanced = smote.fit_resample(X, Y)
print("Balanced Xtrain shape:", Xtrain_balanced.shape)
print("Balanced Ytrain shape:", Ytrain_balanced.shape)
# Out:
# Balanced Xtrain shape: (542, 11)
# Balanced Ytrain shape: (542,)

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(Xtrain_balanced, Ytrain_balanced, random_state=123, test_size=0.2)

# %%
Xtrain.shape
# Out:
# (433, 11)

# %%
Xtest.shape
# Out:
# (109, 11)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
Xtrain = scaler.fit_transform(Xtrain)
Xtrain
# Out:
# array([[ 1.40047367, -0.19696368,  0.20195812, ..., -0.52657966,
#         -0.26792196, -1.19293207],
#        [-0.73500484, -1.00968295, -0.5562125 , ..., -0.52657966,
#         -0.26792196,  0.08247432],
#        [-0.73500484,  0.14822353,  0.10131208, ...,  1.89904791,
#         -0.26792196,  0.08247432],
#        ...,
#        [ 0.23308582,  0.72280732, -0.5562125 , ..., -0.52657966,
#         -0.26792196, -1.19293207],
#        [-0.73500484, -0.32367798, -0.5562125 , ..., -0.52657966,
#         -0.26792196,  0.08247432],
#        [ 0.9746809 , -0.3054719 ,  0.00730854, ..., -0.52657966,
#         -0.26792196,  0.08247432]])

# %%
Xtest = scaler.transform(Xtest)
Xtest
# Out:
# array([[ 0.7013413 , -0.03310899, -0.5562125 , ..., -0.52657966,
#         -0.26792196,  0.08247432],
#        [-0.73500484,  0.37397889, -0.5562125 , ..., -0.52657966,
#         -0.26792196,  0.08247432],
#        [-0.73500484, -1.01769362, -0.5562125 , ...,  1.89904791,
#         -0.26792196, -1.19293207],
#        ...,
#        [-0.03225155,  2.40796179, -0.06975588, ..., -0.52657966,
#         -0.26792196,  0.08247432],
#        [ 0.33273441, -1.90105247,  0.78366565, ..., -0.52657966,
#          3.7324301 ,  1.35788071],
#        [ 0.46560043, -0.15618207, -0.5562125 , ..., -0.52657966,
#         -0.26792196,  0.08247432]])

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB 
model_NB = GaussianNB()                       
model_NB.fit(Xtrain, Ytrain)                  
NB_model = model_NB.predict(Xtest)

# %%
from sklearn.metrics import accuracy_score
acc_NB = accuracy_score(Ytest, NB_model)
acc_NB
# Out:
# 0.8532110091743119

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, NB_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83        56
#            1       0.77      1.00      0.87        53
#
#     accuracy                           0.85       109
#    macro avg       0.88      0.86      0.85       109
# weighted avg       0.89      0.85      0.85       109

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_NB = confusion_matrix(Ytest, NB_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_NB, display_labels = model_NB.classes_)
disp.plot()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier 
model_RF = RandomForestClassifier()                       
model_RF.fit(Xtrain, Ytrain)                  
RF_model = model_RF.predict(Xtest)

# %%
acc_RF = accuracy_score(Ytest, RF_model)
acc_RF
# Out:
# 0.908256880733945

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, RF_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91        56
#            1       0.86      0.96      0.91        53
#
#     accuracy                           0.91       109
#    macro avg       0.91      0.91      0.91       109
# weighted avg       0.91      0.91      0.91       109

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_RF = confusion_matrix(Ytest, RF_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_RF, display_labels = model_RF.classes_)
disp.plot()

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
model_LR = linear_model.LogisticRegression()
model_LR.fit(Xtrain, Ytrain)
LR_model = model_LR.predict(Xtest)

# %%
acc_LR = accuracy_score(Ytest, LR_model)
acc_LR
# Out:
# 0.8532110091743119

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, LR_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.73      0.84        56
#            1       0.78      0.98      0.87        53
#
#     accuracy                           0.85       109
#    macro avg       0.88      0.86      0.85       109
# weighted avg       0.88      0.85      0.85       109

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_LR = confusion_matrix(Ytest, LR_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_LR, display_labels = model_LR.classes_)
disp.plot()

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model_DT = DecisionTreeClassifier()
model_DT.fit(Xtrain, Ytrain)
DT_model = model_DT.predict(Xtest)

# %%
acc_DT = accuracy_score(Ytest, DT_model)
acc_DT
# Out:
# 0.8715596330275229

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, DT_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87        56
#            1       0.85      0.89      0.87        53
#
#     accuracy                           0.87       109
#    macro avg       0.87      0.87      0.87       109
# weighted avg       0.87      0.87      0.87       109

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_DT = confusion_matrix(Ytest, DT_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_DT, display_labels = model_DT.classes_)
disp.plot()

# %% [markdown]
# ### K-Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(Xtrain,Ytrain)
 pred_i = knn.predict(Xtest)
 error_rate.append(np.mean(pred_i != Ytest))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
 markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
acc = []
from sklearn import metrics
for i in range(1,40):
    neigh = KNeighborsClassifier(n_neighbors = i).fit(Xtrain,Ytrain)
    yhat = neigh.predict(Xtest)
    acc.append(metrics.accuracy_score(Ytest, yhat))
    
plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
max_accuracy = max(acc)
optimal_k_value = acc.index(max_accuracy) + 1
print("Maximum accuracy:",max_accuracy,"at K =", optimal_k_value)
# Out:
# Maximum accuracy: 0.8440366972477065 at K = 18

# %% [markdown]
# - The optimal k-value is 18 based on the above charts.

# %%
knn = KNeighborsClassifier(n_neighbors=18)
model_KNN = knn.fit(Xtrain, Ytrain)
KNN_model = knn.predict(Xtest)

# %%
acc_KNN = accuracy_score(Ytest, KNN_model)
acc_KNN
# Out:
# 0.8440366972477065

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, KNN_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.73      0.83        56
#            1       0.77      0.96      0.86        53
#
#     accuracy                           0.84       109
#    macro avg       0.86      0.85      0.84       109
# weighted avg       0.87      0.84      0.84       109

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm_KNN = confusion_matrix(Ytest, KNN_model)
disp = ConfusionMatrixDisplay(confusion_matrix = cm_KNN, display_labels = model_KNN.classes_)
disp.plot()

# %% [markdown]
# # Evaluation

# %%
plt.rcParams["figure.figsize"] = [7,7]
acc = [acc_NB, acc_RF, acc_LR, acc_DT, acc_KNN]
models = ['NB', 'RF', 'LR', 'DT', 'KNN']

plt.plot(models,acc, color = 'green', marker = 'o', markerfacecolor = 'red')
plt.grid(False)
plt.show()

# %% [markdown]
# - RF performs best according to the evaluation conducted with an accuracy of 91%
